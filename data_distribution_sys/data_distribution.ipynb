# %%
import pandas as pd
import numpy as np

# %%
labled = pd.read_csv('labeled shm3.csv')

# %%
labled.head()
# Out:
#   Unnamed: 0                 date  \
# 0          0  2019-11-06 16:06:06
# 1          1  2019-11-06 16:05:28
# 2          2  2019-11-06 16:04:52
# 3          3  2019-11-06 16:04:25
# 4          4  2019-11-06 16:04:25
#
#                                                tweet   user-name  \
# 0                              ابي اروح❤️😞 #ليلة_سهم      vxzo19
# 1  عادي ينعاد امس ☹️♥️♥️♥️♥️ #ليلة_سهم https://t....  ali_saad59
# 2  @Turki_alalshikh اذا الامسيه هذي خاصه ليه تنزل...  sarafhad12
# 3  @PEET_31 ليلة صاغها قلبي ولحنها سهم ♥️ https:/...      Hnm_77
# 4  كل شي صار في ساعة غضب، غضب غضب غضب .. #ليلة_سه...   onclouds1
#
#                                loca  fv_count  rt-count Event name  label
# 0                            Dammam       0.0       0.0        SHM    1.0
# 1  الرياض, المملكة العربية السعودية       0.0       0.0        SHM    1.0
# 2                       Riyadh            0.0       0.0        SHM    0.0
# ...

# %%
labled.label.value_counts()
# Out:
# 1.0    1358
# 0.0     122
# 2.0      20
# Name: label, dtype: int64

# %%
labeled = labled[0:3000]
unlabeled = labled[3000:]

# %%
labeled['label']
# Out:
# 0       1.0
# 1       1.0
# 2       0.0
# 3       1.0
# 4       1.0
#        ...
# 2995    NaN
# 2996    NaN
# 2997    NaN
# 2998    NaN
# 2999    NaN
# Name: label, Length: 3000, dtype: float64

# %%
labeled['label'].replace(float(2),None,inplace=True)

# %%
labeled['label'].dropna(inplace=True)
# Out:
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/pandas/core/series.py:4494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(result)

# %%
len(labeled['label'])
# Out:
# 1484

# %%
labeled['label'].value_counts()
# Out:
# 1.0    1365
# 0.0     119
# Name: label, dtype: int64

# %%
labeled.dropna(how='all',subset=['label'],inplace=True)
# Out:
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
len(labeled)
# Out:
# 1484

# %%
unlabeled['label'] = unlabeled['label'].apply(lambda x: None)
# Out:
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
unlabeled['label'].dropna(inplace=True)
unlabeled.reset_index(inplace=True)

# %%
len(unlabeled)
# Out:
# 28189

# %%
labeled.to_csv('pure_shm_labeled.csv',header=True)

# %%
counter = 0
for index,w in unlabeled.iterrows():
    if index%10 == 0:
        unlabeled.iloc[index] = labeled.iloc[counter]
        if counter >= len(labeled)-1:
            counter = 0
        else:
            counter+=1
# Out:
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
unlabeled.to_csv('test_acc_shm.csv',header=True)

# %%
unlabeled.columns
# Out:
# Index(['index', 'Unnamed: 0', 'date', 'tweet', 'user-name', 'loca', 'fv_count',
#        'rt-count', 'Event name', 'label'],
#       dtype='object')

# %%
del unlabeled['Unnamed: 0']

# %%
del unlabeled['index']

# %%
unlabeled['label'].value_counts()
# Out:
# 1.0    2591
# 0.0     228
# Name: label, dtype: int64

# %%
unlabeled['label'] = unlabeled['label'].apply(lambda x:None)
# Out:
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
unlabeled.head(50)
# Out:
#                    date                                              tweet  \
# 0   2019-11-06 16:06:06                              ابي اروح❤️😞 #ليلة_سهم
# 1   2019-11-06 00:37:37                                أصاااله😩💜 #ليلة_سهم
# 2   2019-11-06 00:37:33  يا احلا مفاجأه صوتي راح 😍\nوصلنا احساسه كيف لو...
# 3   2019-11-06 00:37:21  #ليلة_سهم وش هالليله الطربيه وش هالمتعه وش هال...
# 4   2019-11-06 00:37:21  شابة اشتغل ( مونتاج مقاطع وتصاميم وانفوجرافيك ...
# 5   2019-11-06 00:37:19  ختمت هاشتاق #ليلة_سهم  ع كثر م اتفرج فيديوهات ...
# 6   2019-11-06 00:37:08  #ليلة_سهم \n\nلقطة مستحيل انساها 😭😭❤️❤️❤️\n\n@...
# 7   2019-11-06 00:37:07       تبقى الاول ❤️ #عبدالمجيد_عبدالله \n#ليلة_سهم
# 8   2019-11-06 00:37:02        #ليله_سهم غيرت كلامي امس , لاني خقيت حرفياً
# 9   2019-11-06 00:36:53  #ليلة_سهم \nلا تخاف من الزمان الزمن ماله امان ...
# 10  2019-11-06 16:05:28  عادي ينعاد امس ☹️♥️♥️♥️♥️ #ليلة_سهم https://t....
# ...

# %%
counter_begin = 0
counter_end=500
for i in range(0,35):
    unlabeled[counter_begin:counter_end].to_csv('doc{}.csv'.format(i))
    counter_begin+=500
    counter_end+=500
